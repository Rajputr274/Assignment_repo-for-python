# %%
n1=int(input("enter first no.="))
n2=int(input("enter second no.="))
print("Before swapping",n1,n2)       
z=n1
n1=n2
n2=z
print("after swapping",n1,n2)
# Out:
# Before swapping 10 20
# after swapping 20 10

# %%
1+1
# Out:
# 2

# %%
char1=input("Name of Char1.=")
char2=input("Name of Char2.=")
print("Before swapping=",char1,char2)       
z=char1
char1=char2
char2=z
print("After swapping=",char1,char2)
# Out:
# Name of Char1.= rahul
# Name of Char2.=
# Before swapping= rahul
# Before swapping=  rahul

# %%
n1=int(input("enter first no 1.="))
char2=input("Name of Char2.=")
print("Before swapping=",n1,char2)       
z=n1
n1=char2
char2=int(z)
print("After swapping=",n1,char2)
print(type(n1))
print(type(char2))
# Out:
# enter first no 1.= 200
# Name of Char2.= Java
# Before swapping= 200 Java
# After swapping= Java 200
# <class 'str'>
# <class 'int'>

# %%
#Banking and Transactions

# %%
a=int(input("enter your current balance="))
print(f" Your current balance is={a}")
b=int(input("enter deposit amaount="))
c=a+b
print(f"Amount after deposit={c}")
# Out:
# enter your current balance= 10000
#  Your current balance is=10000
# enter deposit amaount= 5000
# Amount after deposit=15000

# %%
a=int(input("enter your current balance="))
print(f" Your current balance is={a}")
b=int(input("enter withdrawal amaount="))
c=a-b
print(f"Amount after Withdrawal={c}")
# Out:
# enter your current balance= 12000
#  Your current balance is=12000
# enter withdrawal amaount= 3000
# Amount after Withdrawal=9000

# %%
a=int(input("enter your cart items"))
print(f"items in your cart{a}")
b=int(input("new added items="))
c=a+b
print(f"your total items in Cart={c}")
# Out:
# enter your cart items 5
# items in your cart5
# new added items= 3
# your total items in Cart=8

# %%
a=int(input("price before discount="))
print("final price before discount",a)
b=a-a*(20/100)
print(f"final Price after discount={b}")
print(f"final Price after discount={int(b)}")
# Out:
# price before discount= 1000
# final price before discount 1000
# final Price after discount=800.0
# final Price after discount=800

# %%
#Academic Calculations

# %%
a=int(input("obtain marks="))
b=int(input("total marks="))
c=a/b*100
print(f"percentage of student={c}")
# Out:
# obtain marks= 430
# total marks= 500
# percentage of student=86.0

# %%
a=int(input("enter marks in subject 1 ="))
b=int(input("enter marks in subject 2 ="))
c=int(input("enter marks in subject 3 ="))
d=int(input("enter marks in subject 4 ="))
e=a+b+c+d
f=e/4
print(f"total no. of Marks obtained={e}")
print(f"averge no. of Marks obtained={f}")
# Out:
# enter marks in subject 1 = 80
# enter marks in subject 2 = 75
# enter marks in subject 3 = 90
# enter marks in subject 4 = 85
# total no. of Marks obtained=330
# averge no. of Marks obtained=82.5

# %%
a=int(input("enter number 1 ="))
b=int(input("enter number 2 ="))
c=int(input("enter number 3 ="))
d=(a+b+c)/3
print(f"average of no.s={d}")
# Out:
# enter number 1 = 25
# enter number 2 = 35
# enter number 3 = 45
# average of no.s=35.0

# %%
#Finance & Business Calculations

# %%
a=int(input("enter Cost Price="))
b=int(input("enter selling price="))
c=b-a
print(f"profit={c}")
# Out:
# enter Cost Price= 500
# enter selling price= 600
# profit=100

# %%
p=int(input("enter amount of Principal="))
r=int(input("enter rate="))
t=int(input("enter time period="))
i=(p*r*t)/100
print(f"simple intrest={i}")
# Out:
# enter amount of Principal= 10000
# enter rate= 5
# enter time period= 2
# simple intrest=1000.0

# %%
p=int(input("enter principal="))
r=int(input("enter rate="))
t=int(input("enter time period="))
A=p*((1+r/100)**t)
print(A)
CI=A-p
print(f"Compound Intrest for 2 year is={CI}")
# Out:
# enter principal= 10000
# enter rate= 5
# enter time period= 2
# 11025.0
# Compound Intrest for 2 year is=1025.0

# %%
a=int(input("enter income ="))
t_r=int(input("Tax rate ="))
tax=a*(t_r/100)
print(f"total tax on your amount={tax}")
# Out:
# enter income = 500000
# Tax rate = 10
# total tax on your amount=50000.0

# %%
a=int(input("enter initial value="))
b=int(input("final value="))
c=b-a
p_c=(c/a)*100
print(f"percentage changes ={p_c}")
# Out:
# enter initial value= 200
# final value= 250
# percentage changes =25.0

# %%
#Conversions

# %%
a=True
b=int(a)
print(b)
# Out:
# 1

# %%
a=False
b=int(a)
print(b)
# Out:
# 0

# %%
a=45.67
b=str(a)
print(type(b),(b))
# Out:
# <class 'str'> 45.67

# %%
a=int(input("enter temp in degree celcius="))
b=(a*9/5)+32
print(f"temp in fahrenheit={b}")
# Out:
# enter temp in degree celcius= 20
# temp in fahrenheit=68.0

# %%
a=int(input("enter temp in degree fahrenheit="))
b=(a-32)*5/9
print(f"temp in degree celcius={b}")
# Out:
# enter temp in degree fahrenheit= 50
# temp in degree celcius=10.0

# %%
a=int(input("enter no="))
b=bin(a)
print(f"integer to binary={b}")
# Out:
# enter no= 25
# integer to binary=0b11001

# %%
a=int(input("enter the base of triangle="))
b=int(input("enter the Height of triangle="))
c=(1/2)*a*b
print(f"Area of triangle={c}")
# Out:
# enter the base of triangle= 10
# enter the Height of triangle= 6
# Area of triangle=30.0

# %%
a=int(input("enter side of square="))
b=4*a
print(f"perimeter of square= {b}")
# Out:
# enter side of square= 9
# perimeter of square= 36

# %%
a=int(input("enter Radius of circle="))
b=a*2
print(f"Diameter of circle is = {b}")
# Out:
# enter Radius of circle= 14
# Diameter of circle is = 28

# %%
a=int(input("enter side of cube="))
b=a**3
print(f"volume of cube= {b}")
# Out:
# enter side of cube= 5
# volume of cube= 125

# %%
l=int(input("enter the length="))
b=int(input("enter the breadth="))
h=int(input("enter the height="))
S_A= 2*((l*b)+(b*h)+(h*l))
print(f"surface area of cuboid= {S_A}")
# Out:
# enter the length= 4
# enter the breadth= 3
# enter the height= 2
# surface area of cuboid= 52

# %%
#Mathematical Expressions

# %%
x=int(input("enter value of X="))
y=int(input("enter value of Y="))
c=(x+y)**2
print(f"sqaure of sum is = {c}")
# Out:
# enter value of X= 5
# enter value of Y= 7
# sqaure of sum is = 144

# %%
x=int(input("enter value of X="))
b=((x)**2)-(4*(x))+(4)
print(f"simplification of the expression {b}")
# Out:
# enter value of X= 3
# simplification of the expression 1

# %%
a=int(input("enter value of a="))
b=int(input("enter value of b="))
c=(a+b)*(a-b)
print(f"solution of (a+b)(a-b)= {c}")
# Out:
# enter value of a= 6
# enter value of b= 2
# solution of (a+b)(a-b)= 32

# %%
a=int(input("enter value of a="))
b=int(input("enter value of b="))
c=(a)**3+(b)**3
print(f"solution of = {c}")
# Out:
# enter value of a= 1
# enter value of b= 2
# solution of = 9

# %%
x=int(input("enter value of X="))
y=int(input("enter value of Y="))
c=(x-y)**2
print(f"solution = {c}")
# Out:
# enter value of X= 10
# enter value of Y= 6
# solution = 16

# %%
x=int(input("enter value of X="))
y=int(input("enter value of Y="))
c=(x)**3-(y)**3
print(f"solution = {c}")
# Out:
# enter value of X= 4
# enter value of Y= 1
# solution = 63

# %%
full_name=input("enter your full name=")
profession=input("enter your profession=")
favorite_Quote=input("enter your favorite Quote=")
year_of_experience=input("enter your year of experience=")
print("--------------------------------------------------")
print(f"Name:{full_name}")
print(f"Profession:{profession}")
print(f"Quote:{favorite_Quote}")
print(f"Experience:{year_of_experience}")
print("--------------------------------------------------")
# Out:
# enter your full name= Rahul Rajput
# enter your profession= Data Scientist
# enter your favorite Quote= Massive heights demand massive grinds means
# enter your year of experience= 1.5 Year
# --------------------------------------------------
# Name:Rahul Rajput
# Profession:Data Scientist
# Quote:Massive heights demand massive grinds means
# Experience:1.5 Year
# --------------------------------------------------

# %%
Movie_name=input("enter movie name=")
name=input("enter your full name=")
seat_no=input("enter your seat no.=")
time=input("enter time of your movie=")
print("--------------------------------------------------")
print(f"Movie:{Movie_name}")
print(f"Name:{name}")
print(f"Seat:{seat_no}")
print(f"time:{time}")
print(f"enjoy the Show!")
print("--------------------------------------------------")
# Out:
# enter movie name= Dhurandar
# enter your full name= Rahul Rajput
# enter your seat no.= A3
# enter time of your movie= 12:30 PM
# --------------------------------------------------
# Movie:Dhurandar
# Name:Rahul Rajput
# Seat:A3
# time:12:30 PM
# enjoy the Show!
# --------------------------------------------------

# %%
# 1. Write a Python program to print all odd and even numbers from 1 to 20.

for i in range(1,21):
    value=i%2
    if value==0:
        print(i,"even")
    else:
        print(i,"odd")
# Out:
# 20 even

# %%
# 2. Write a Python program to generate all multiples of 12. 
num1=12
num2=10
for i in range(1,num2+1):

    print(f"{num1} x {i} = {num1*i}")
# Out:
# 12 x 1 = 12
# 12 x 2 = 24
# 12 x 3 = 36
# 12 x 4 = 48
# 12 x 5 = 60
# 12 x 6 = 72
# 12 x 7 = 84
# 12 x 8 = 96
# 12 x 9 = 108
# 12 x 10 = 120

# %%
# 3. Write a Python program to generate a table of a number provided by the user.

num1=int(input("enter your no.= "))
num2=10
for i in range(1,num2+1):
    print(f"{num1} x {i} = {num1*i}")
# Out:
# enter your no.=  4
# 4 x 1 = 4
# 4 x 2 = 8
# 4 x 3 = 12
# 4 x 4 = 16
# 4 x 5 = 20
# 4 x 6 = 24
# 4 x 7 = 28
# 4 x 8 = 32
# 4 x 9 = 36
# 4 x 10 = 40

# %%
num1=int(input("enter your no.= "))
res=0
for i in range (1,num1+1):
    if num1%i==0:
        res+=1
        print(i)
# Out:
# enter your no.=  8
# 1
# 2
# 4
# 8

# %%
# 4. Write a Python program to check if a number provided by the user is prime or not. 
num1=int(input("enter your no.= "))
factor=0

for i in range (1,num1+1):
    if num1%i==0:
        print(f"{num1} is divisible by {i}")
        factor+=1

if factor==2:
    print(f"{num1} is a prime number")
else:
    print(f"{num1} is not a prime number")
# Out:
# enter your no.=  17
# 17 is divisible by 1
# 17 is divisible by 17
# 17 is a prime number

# %%
# 5. Write a Python program to calculate the sum of numbers between a starting and 
# # ending point provided by the user. 

str_num=int(input("enter start no. = "))
end_num=int(input("enter end no. = "))
add=0
for i in range (str_num,end_num+1):
    
    add+=i
    # print(add)
print(add)
# Out:
# enter start no. =  1
# enter end no. =  5
# 15

# %%
# 6. Write a Python program to calculate the product of numbers between a starting 
# and ending point provided by the user

str_num=int(input("enter start no. = "))
end_num=int(input("enter end no. = "))
add=1
for i in range (str_num,end_num+1):
    print(i)
    add*=i
print(add)
# Out:
# enter start no. =  2
# enter end no. =  5
# 2
# 3
# 4
# 5
# 120

# %%
# 7. Write a Python program to generate the Fibonacci sequence up to a specified number of terms
n=6
a=0
b=1
for i in range(n-1):
    c=a
    a=b
    b=b+c
    print(a)
# Out:
# 1
# 1
# 2
# 3
# 5

# %%
# Out:
# Enter the number of terms:  6
# Fibonacci sequence:
# 0 1 1 2 3 5

# %%
# 8. Write a Python program to calculate the factorial of a number provided by the 
# user. 

num=int(input("enter your no. = "))
fact=1

for i in range(1,num+1):
    print(i)
    fact*=i
print(fact)
# Out:
# enter your no. =  5
# 1
# 2
# 3
# 4
# 5
# 120

# %%
# 9. Write a Python program to find the greatest character from the string "python". 

str1="python"
char=str1[0]
for i in str1:
    if i>char:# here i is first char and char is the next char of string 
        char=i
        print(char)
print(char)
# Out:
# y
# y

# %%
# 10. Write a Python program to display all letters except 'm' and 'i' from the string 
# "Dreamer infotech". 

str1="Dreamer infotech"
char=0
for i in str1:
    if i!="m" and i!="i":
        print(i,end="")
  
# print (str1)
# Out:
# Dreaer nfotech

# %%
# 11. Write a Python program to print alternate characters from a given string. 

str1="Dreamer infotech"
size=len(str1)
char=1
for i in range (0,size-1,2):
    print(str1[i],end=" ")
# Out:
# D e m r i f t c

# %%
# 12. Write a Python program to reverse a string entered by the user.

str1=input("enter text = ")
rev=""
for i in str1:
    rev= i+rev
print(rev)
# Out:
# enter text =  rahul
# luhar

# %%
# 13. Write a Python program to count the total number of characters in a string 
# # entered by the user. 

str1=input("enter text : ")
size=len(str1)

for i in range (size):
    i+=1
print(i)
# Out:
# enter text :  rahul
# 5

# %%
# 14. Write a Python program to check whether a string entered by the user is a 
# palindrome. 

str1=input("enter text : ")

rev=""

for i in str1:
    rev=i+rev
if rev==str1:
    print("palindrome")
else:
    print(" not palindrome")
# Out:
# enter text :  nitin
# palindrome

# %%
# 15. Write a Python program that allows the user to search for a character within a 
# given string. 


str1="enter text"
char=input("enter text to search : ")
for i in str1:
    if char in str1:
        print("yes",str1)
        break
    else:
        print("no")
# Out:
# enter text to search :  t
# yes enter text

# %%
# 16. Write a Python program to filter out all vowels and consonants from a string 
# entered by the user. 

str1=input("enter text : ")
vowels=""
consonents=""
for i in str1:
    if i in "aeiou":
        vowels+=i
    else:
        consonents+=i
        
print(f"count of volwels in {str1} is = {len(vowels)}")
print(f"count of consonents in {str1} is = {len(consonents)}")
# Out:
# enter text :  rahul
# count of volwels in rahul is = 2
# count of consonents in rahul is = 3

# %%
# 17. Write a Python program to filter out duplicate characters from a string entered by 
# the user. 

str1="dummy"
char=""
for i in  str1:
    if i not in char:
        char+=i
    print(i)
        
print(char)
# Out:
# d
# u
# m
# m
# y
# dumy

# %%
# 18. Write a Python program to display all possible pairs of 3. 

for i in range(1,4):
    for j in range(1,4):
        if i==3 or j==3:
            print(f"{i} : {j}")
# Out:
# 1 : 3
# 2 : 3
# 3 : 1
# 3 : 2
# 3 : 3

# %%
# 19. Write a Python program to generate the pattern of the letter H. 

n=7
for i in range(n):
    for j in range(n):
        if i==n//2 or (j==0 or j==n-1):
            print("*",end=" ")
        else:
            print(" ",end=" ")
    print()
# Out:
# *           *
# *           *
# *           *
# * * * * * * *
# *           *
# *           *
# *           *

# %%
# 20. Write a Python program to find duplicate letters between two strings.
# Example: In "virat" and "rohit", the duplicate letter is "r". 

str1="virat"
str2="rohit"
for i in  str1:
    for j in str2:
        if i==j:
            print("duplicate",i)
# Out:
# duplicate i
# duplicate r
# duplicate t

# %%
# 21. Write a Python program to display the squares of numbers from 1 to 10. 

n=10
for i in range(1,n+1):
    i*=i
    print(i,end=" ")
# Out:
# 1 4 9 16 25 36 49 64 81 100

# %%
# 22. Given a string text = "python", calculate the sum of the indices of its 
# characters without using the range() or len() functions. 

text="python"
index=0
total=0
for i in text:
    total=total + index
    index+=1
print(total)
# Out:
# 15

# %%
# 23. Given: text = "python programming" 
# Goal: Count how many vowels are in the string. 
# Constraint: Do not use indexing (text[i]) or slicing (text[:]). 


text = "python programming"
vowels=0
for i in text:
    if i in "aeiouAEIOU":
        vowels+=1
print(f"count of vowels : {vowels}")
# Out:
# count of vowels : 4

# %%
# 24. Given: text = "programming" 
# Goal: Print all characters that repeat in the string. 


text ="programming"
char=""
for i in text:
    if i in char:
        print(i)
        
        
    else:
        char+=i
# Out:
# r
# m
# g

# %%
# 25. Given : 01275623 
# Write a Python program to find and print the greatest character in the string. 

given="01275623"
count=0
for i in given:
    # print(i)
    if int(i)>count:
        count=int(i)
print(count)
# Out:
# 7

# %%
# . Given : "rahul" 
# Write a Python program to find and print the greatest character in the string. 

text="rahul"

char=text[0]
for i in text:
    
    if i>char:
        char=i
print(char)
# Out:
# u

# %%
# 26. Given: text = "knowyourself" 
# Goal: Find and print the first character that repeats. 


text = "knowyourself" 

char=""

for i in text:

    if i in char:
        print(f" first repeated char is : {i}")
        
    else:
        char+=i
# Out:
#  first repeated char is : o

# %%
# 27. Give : text=”if you think you can not do, you can not show think wisely”  
# Goal: Print the alternate words  
# Constraint: Do not use space between words more than once . 


text="if you think you can not do, you can not show think wisely"
count=0

for i in text:
    if i == " ":
        count+=1
        if count%2==1:
            print("",end=" ")
    else:
        if count%2==0:
            print(i,end="")
# Out:
# if think can do, can show wisely

# %%
# 28. Given: text = "knowyourself" 
# Goal: Find and print the alternate characters. 


text = "knowyourself"

char=0
for i in text:
    if char%2==0: 
        print(i,end="")
    char+=1
# Out:
# koyusl

# %%
# 29. Take two numbers from the user: start and end. Print a string labeling each 
# number in that range as Odd or Even. 
# Output_format : 3:Odd 4:Even 5:Odd 6:Even 7:Odd 8:Even 9:Odd 



n1=int(input("enter first no. = "))
n2=int(input("enter second no. = "))

for i in range(n1,n2+1):
    if i%2==0:
        print(f"{i}:even",end=" ")
    else:
        print(f"{i}:odd",end=" ")
# Out:
# enter first no. =  2
# enter second no. =  10
# 2:even 3:odd 4:even 5:odd 6:even 7:odd 8:even 9:odd 10:even

# %%
# 30.Find the sum of string “198765456412”. 

str1="198765456412"
count=0
for i in str1:
    count=count+int(i)
    # print(i)
    

print(f" sum of each no.in string {str1} is {count}")
# Out:
#  sum of each no.in string 198765456412 is 58

# %%
# 31.Count how many digits in the string are greater than 5 from text = "1234567890". 

text ="1234567890"
count=0

for i  in text:
    if int(i)>5:
        # print(i)
        count= count+1
        

print(f"count of digits which are greater than 5 is : {count}")
# Out:
# count of digits which are greater than 5 is : 4

# %%
# 32.Task: Replace Character in String 
# Write a program that takes a string input from the user, then asks for a character 
# to replace and the character to replace it with. The program should output the 
# modified string where all occurrences of the specified character are replaced by 
# the replacement character. 



str1= input("enter text : ")
find_text=input("enter text to find : ")
replace_text=input("enter text to replace : ")
new_str=""

for i in str1:
    if i==find_text:
        new_str+=replace_text
        
    else:
        new_str+=i
        
        
    
print(new_str)
# Out:
# enter text :  rahul rajput
# enter text to find :  r
# enter text to replace :
#  ahul  ajput

# %%
# 33.Replace Spaces with Underscores Replace all spaces in a string with underscores (_)  


str1= input("enter text : ")

replace_text="_"

new_str=""

for i in str1:
    if i ==" ":
        new_str+=replace_text
    else:
        new_str+=i
print(new_str)
# Out:
# enter text :  rahul singh rajput
# rahul_singh_rajput

# %%
# 34.Remove Duplicate characters from the string given by the user then print the final 
# output. 


str1="programming"
char=""

for i in str1:
    if i not in char:
        char+=i
print(char)
# Out:
# progamin

# %%
# 35.Take string from user and Replace every vowel in the string with an asterisk *. 

str1="programming"

new_str=""

for i in str1:
    if i in "aeiouAEIOU":
        new_str+="*"
    else:
        new_str+=i
print(new_str)
# Out:
# pr*gr*mm*ng

# %%
# 36.Count only words not spaces. 
# Entered a string: Hello coders from Success24 
# Number of words: 4 

string="Hello coders from Success24"
count=1
for i in string:
    if i==" ":
        
        count+=1
print(count )
# Out:
# 4

# %%
# 37.Task: Count how many uppercase and lowercase letters are in a string.

str1=input("enter text: ")
lower_count=0
upper_count=0
for i in str1:
    if "A"<=i<="Z":
        upper_count+=1
    elif "a"<=i<="z":
        lower_count+=1
    else:
        print(" ")
print(f"count of lower case letters : {lower_count}")
print(f"count of upper case letters : {upper_count}")
# Out:
# enter text:  souMya
# count of lower case letters : 5
# count of upper case letters : 1

# %%
# 38.Task: Print all characters from the string that are at odd indices. 


str1="programming"
new_str=""

for i in range (1,len(str1),2):
    # if i%2!=0:
    new_str+=str1[i]

print(new_str)
# Out:
# rgamn

# %%
# 39.Task: Create a new string by removing all spaces from the input string.

str1="how are you all"
new_str=""

for i in str1:
    if i!=" ":
        new_str+=i
    else:
        continue
print(new_str)
# Out:
# howareyouall

# %%
# 40.Count how many digits in a string entered by the user. 
# text=”sytax_error2806 hai ”

text="sytax_error2806 hai"
count=0

for i in text:
    if i in "0123456789":
        count+=1
    else:
        i+=i
print(f"count of digits in string : {count}")
# Out:
# count of digits in string : 4

# %%
# 41.Count only alphabets (both uppercase and lowercase). 
# Enter a string:  this123 i am  
# Number of letters: 7 

str1="this123 i am"
count=0

for i in str1:
    if i  not in "0123456789" and i!=" ":
        count+=1
    else:
        i+=i
print(f"count of alphabets in string : {count}")
# Out:
# count of alphabets in string : 7

# %%
"""42.You are managing a simple banking system that tracks the balance at the end of 
each day over 10 days. Each day, the balance increases by 100 units starting from 100 
on day 1, 200 on day 2, and so on. You want to print the current day’s balance along with 
the previous day’s balance. For day 1, the previous day’s balance is 0. 
Sample output: 
Day 1: Balance = 100, Previous Day Balance = 0 
Day 2: Balance = 200, Previous Day Balance = 100 
Day 3: Balance = 300, Previous Day Balance = 200 
... 
Day 10: Balance = 1000, Previous Day Balance = 900 """


days=int(input("enter no. of days : "))
balance=0

for i in range(1,days+1):
    if days>=1:
        
        balance+=100
    print(f"for day{i} the balance = {balance} , previous balance is = {balance-100}")
# Out:
# enter no. of days :  5
# for day1 the balance = 100 , previous balance is = 0
# for day2 the balance = 200 , previous balance is = 100
# for day3 the balance = 300 , previous balance is = 200
# for day4 the balance = 400 , previous balance is = 300
# for day5 the balance = 500 , previous balance is = 400
